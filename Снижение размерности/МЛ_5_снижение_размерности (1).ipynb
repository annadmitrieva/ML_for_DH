# %% [markdown]
# # Снижение размерности матриц текстов

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD

# %% [markdown]
# Мы будем работать с тем же датасетом, что и в прошлый раз.

# %%
from sklearn.datasets import fetch_20newsgroups

# %% [markdown]
# Пока что загрузим только тренировочный сабсет:

# %%
newsgroups = fetch_20newsgroups(subset='train')

# %%
list(newsgroups.target_names)
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
newsgroups.data[10]
# Out:
# 'From: irwin@cmptrc.lonestar.org (Irwin Arnstein)\nSubject: Re: Recommendation on Duc\nSummary: What\'s it worth?\nDistribution: usa\nExpires: Sat, 1 May 1993 05:00:00 GMT\nOrganization: CompuTrac Inc., Richardson TX\nKeywords: Ducati, GTS, How much? \nLines: 13\n\nI have a line on a Ducati 900GTS 1978 model with 17k on the clock.  Runs\nvery well, paint is the bronze/brown/orange faded out, leaks a bit of oil\nand pops out of 1st with hard accel.  The shop will fix trans and oil \nleak.  They sold the bike to the 1 and only owner.  They want $3495, and\nI am thinking more like $3K.  Any opinions out there?  Please email me.\nThanks.  It would be a nice stable mate to the Beemer.  Then I\'ll get\na jap bike and call myself Axis Motors!\n\n-- \n-----------------------------------------------------------------------\n"Tuba" (Irwin)      "I honk therefore I am"     CompuTrac-Richardson,Tx\nirwin@cmptrc.lonestar.org    DoD #0826          (R75/6)\n-----------------------------------------------------------------------\n'

# %%
len(newsgroups.data)
# Out:
# 11314

# %%
len(list(set(newsgroups.target)))
# Out:
# 20

# %%
n_features = 1000 # максимальное количество слов в матрице "документы х слова" (= top1000 частотных их всех в корпусе)
n_components = 7 # число тем в корпусе
n_top_words = 20 # порог частотности для визуализаций

# %% [markdown]
# Попробуем чуть более продвинутую конфигурацию TfidfVectorizer'а. В частности, ограничим размер словаря (max_features), а также будем игнорировать слишком редкие или слишком частотные слова (max_df и min_df).

# %% [markdown]
# Здесь и далее часть кода по https://github.com/nstsj/ML_for_NLP/blob/main/6_dimred/dimred_for_texts(LDA%2BLSA).ipynb.

# %%
tf_vectorizer = TfidfVectorizer(max_df=0.7, min_df=5, # игнорируем слова,которые только в 5 документах или в 70% документов.
                                max_features=n_features,
                                stop_words='english')

X_tf = tf_vectorizer.fit_transform(newsgroups.data)

# %%
display(X_tf.shape) # матрица "документы x слова"
# Out:
# (11314, 1000)

# %% [markdown]
# ## Визуализация с t-SNE

# %%
from sklearn.manifold import TSNE

# %%
# %%time
X_embedded = TSNE(n_components=2, init='random', perplexity=3).fit_transform(X_tf)
# Out:
# CPU times: user 2min 10s, sys: 1.92 s, total: 2min 12s
# Wall time: 2min 19s

# %%
X_embedded.shape
# Out:
# (11314, 2)

# %%
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(X_embedded[:,0], X_embedded[:,1], c=newsgroups.target)
plt.show()

# %%
# %%time
X_embedded_30 = TSNE(n_components=2, init='random', perplexity=30).fit_transform(X_tf)
# Out:
# CPU times: user 2min 28s, sys: 1.87 s, total: 2min 30s
# Wall time: 2min 31s

# %%
X_embedded_30.shape
# Out:
# (11314, 2)

# %%
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(X_embedded_30[:,0], X_embedded_30[:,1], c=newsgroups.target)
plt.show()

# %% [markdown]
# ## LSA (Latent Semantic Analysis)

# %% [markdown]
# Метод главных компонент в sklearn не работает с разреженными матрицами, поэтому для текстов рекомендуется использовать латентно-семантический анализ при помощи класса TruncatedSVD.

# %%
lsa_model = TruncatedSVD(n_components=100, n_iter=10)

lsa_topic_matrix = lsa_model.fit_transform(X_tf)

# %%
# матрица тем
lsa_topic_matrix.shape
# Out:
# (11314, 100)

# %% [markdown]
# Видно, что вторая компонента объясняет больше всего дисперсии (хотя тоже очень мало):

# %%
lsa_model.explained_variance_ratio_
# Out:
# array([0.0036485 , 0.01148966, 0.01066464, 0.00835132, 0.00742669,
#        0.00700052, 0.00661221, 0.00649316, 0.00610941, 0.00573713,
#        0.00552077, 0.00526359, 0.00498587, 0.00474531, 0.00472057,
#        0.00460462, 0.00451089, 0.00428447, 0.00423691, 0.00418552,
#        0.0041385 , 0.0040585 , 0.00402749, 0.0039539 , 0.00388502,
#        0.00386038, 0.00374661, 0.00373193, 0.00367726, 0.00355032,
#        0.00352198, 0.00346938, 0.00340649, 0.00337655, 0.0033527 ,
#        0.00327664, 0.00322639, 0.00314748, 0.00309287, 0.0030716 ,
#        0.00302493, 0.00300429, 0.00298119, 0.00294789, 0.00293226,
#        0.002888  , 0.00286395, 0.00282142, 0.00280942, 0.00277525,
#        0.00274073, 0.00272689, 0.0026906 , 0.00267451, 0.00265075,
#        0.00262788, 0.00261816, 0.00257392, 0.00256569, 0.00254064,
#        0.0025093 , 0.00249902, 0.00248894, 0.00247485, 0.00245584,
#        0.0024426 , 0.00241876, 0.00240096, 0.00238728, 0.00236212,
#        0.00234815, 0.00233026, 0.00231184, 0.00229946, 0.00228239,
#        0.0022624 , 0.00224607, 0.00223549, 0.00221447, 0.00220361,
#        0.00218806, 0.00218483, 0.00217454, 0.00214884, 0.00214464,
#        0.00213514, 0.00212547, 0.00210369, 0.00208142, 0.00206213,
#        0.00205797, 0.00204604, 0.00202305, 0.00201299, 0.00200331,
#        0.00198304, 0.00196363, 0.0019543 , 0.0019294 , 0.0019217 ])

# %% [markdown]
# Всего 100 компонент объясняют 33% дисперсии:

# %%
np.sum(lsa_model.explained_variance_ratio_)
# Out:
# 0.3360401386327744

# %% [markdown]
# Дополненный кусочек про просмотр главных слов каждой компоненты, который объясняется ниже:

# %%
def plot_top_words(model, feature_names, n_top_words, title, n_components, max_plots=7):

    fig, axes = plt.subplots(1, max_plots, figsize=(25, 10)) # параметры отображения
    axes = axes.flatten()
    all_features = {} # словарь для сохранения ключевых слов для тем


    for topic_idx, topic in enumerate(model.components_):
      if topic_idx < max_plots:
        top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]

        # строка для сохранения темы и слов в словарь
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f'Topic {topic_idx +1}',
                     fontdict={'fontsize': 13})
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=10)
        for i in 'top right left'.split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=14)


    plt.show()

# %%
tf_feature_names = tf_vectorizer.get_feature_names_out()
plot_top_words(lsa_model, tf_feature_names, 30, 'Распределение слов по темам, LSA-модель', n_components)

# %% [markdown]
# Можно посмотреть, к какому топику принадлежит каждый документ:

# %%
for n in range(10):
    topic_most_pr = lsa_topic_matrix[n].argmax()
    print("doc: {} topic: {}\n".format(n,topic_most_pr))
# Out:
# doc: 0 topic: 32
#
# doc: 1 topic: 0
#
# doc: 2 topic: 0
#
# doc: 3 topic: 0
#
# doc: 4 topic: 0
#
# doc: 5 topic: 0
#
# doc: 6 topic: 0
#
# doc: 7 topic: 55
#
# doc: 8 topic: 0
#
# doc: 9 topic: 0

# %% [markdown]
# ## LDA (Latent Dirichlet Allocation)

# %%
lda = LatentDirichletAllocation(n_components=100)

lda.fit(X_tf)
# Out:
# LatentDirichletAllocation(n_components=100)

# %%
# матрица "темы x слова": с какой вероятностью каждая тема генерирует каждое слово в корпусе
lda.components_
# Out:
# array([[0.52112598, 0.01      , 0.01      , ..., 0.01      , 0.01      ,
#         0.19837717],
#        [0.01      , 0.01      , 0.01      , ..., 0.01      , 0.01      ,
#         0.01      ],
#        [0.01      , 0.01      , 0.01      , ..., 0.01      , 0.01      ,
#         0.01      ],
#        ...,
#        [0.01      , 0.01      , 0.01      , ..., 0.01      , 0.01      ,
#         0.01      ],
#        [0.01      , 0.01      , 0.01      , ..., 0.01      , 0.01      ,
#         0.01      ],
#        [0.01      , 0.01      , 0.01      , ..., 0.01      , 0.01      ,
#         0.01      ]])

# %% [markdown]
# Можно посмотреть на распределение документов по темам:

# %%
# ряды - id документов, колонки - id топиков, ячейки - вероятность отнесения документа к топику.
doc_topic = lda.transform(X_tf)

# %%
doc_topic.shape
# Out:
# (11314, 100)

# %%
# ряды - id документов, колонки - id топиков, ячейки - вероятность отнесения документа к топику.
pd.DataFrame(doc_topic).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.001974  0.001974  0.001974  0.001974  0.001974  0.001974  0.001974
# 1  0.001978  0.001978  0.001978  0.001978  0.001978  0.712634  0.001978
# 2  0.001174  0.001174  0.001174  0.001174  0.001174  0.153891  0.001174
# 3  0.001395  0.001395  0.001395  0.001395  0.001395  0.001395  0.001395
# 4  0.001540  0.001540  0.001540  0.001540  0.001540  0.683924  0.001540
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.001974  0.001974  0.001974  ...  0.001974  0.001974  0.001974  0.001974
# 1  0.001978  0.001978  0.001978  ...  0.001978  0.001978  0.001978  0.001978
# 2  0.001174  0.001174  0.001174  ...  0.001174  0.001174  0.001174  0.001174
# 3  0.001395  0.001395  0.001395  ...  0.001395  0.001395  0.001395  0.001395
# 4  0.001540  0.001540  0.001540  ...  0.001540  0.001540  0.001540  0.001540
#
#          94        95        96        97        98        99
# 0  0.001974  0.001974  0.001974  0.001974  0.001974  0.001974
# 1  0.001978  0.001978  0.001978  0.001978  0.001978  0.001978
# 2  0.001174  0.001174  0.001174  0.001174  0.001174  0.001174
# 3  0.001395  0.001395  0.001395  0.001395  0.001395  0.001395
# 4  0.001540  0.001540  0.001540  0.001540  0.001540  0.001540
#
# [5 rows x 100 columns]

# %% [markdown]
# Попробуем посмотреть, какие слова входят в конкретную компоненту.

# %% [markdown]
# np.argsort() возвращает индексы для сортировки массива, но в обратном порядке (т.е. слова с самыми большими значениями будут в конце отсортированного массива). Мы возьмем последние N самых значимых слов.

# %%
top_features_ind = lda.components_[0].argsort()[:-n_top_words - 1:-1]

# %%
top_features_ind
# Out:
# array([617, 337, 808, 814, 182, 433, 331, 338, 573, 151, 721, 781, 975,
#        838, 751, 951, 942, 296, 643, 915])

# %% [markdown]
# Теперь возьмем слова, находящиеся в списке признаков под этими индексами.

# %%
tf_feature_names = tf_vectorizer.get_feature_names_out()

top_features = [tf_feature_names[i] for i in top_features_ind]

# %% [markdown]
# Посмотрим на самые значимые слова и их веса:

# %%
weights = lda.components_[0][top_features_ind]

# %%
print(list(zip(top_features, weights)))
# Out:
# [('mouse', 37.77883074039439), ('driver', 9.373699371622498), ('seen', 1.9695696668323714), ('serial', 1.8725087862194587), ('bus', 1.7169217387595637), ('gov', 1.6075010193369221), ('don', 1.545950406962318), ('drivers', 1.4763058910801963), ('machine', 1.3995236456040239), ('bbs', 1.3672712786666925), ('problem', 0.9617457217199694), ('running', 0.9571352116251516), ('win', 0.8332480903615298), ('sorry', 0.8285525780638179), ('recently', 0.8223074246432551), ('version', 0.7880715487694517), ('using', 0.7541883302669906), ('dead', 0.6621178659647535), ('non', 0.6023014278270427), ('try', 0.5961891701770563)]

# %% [markdown]
# Эти слова и их веса можно отрисовать как бар-чарт:

# %%
fig, ax = plt.subplots(figsize=(7, 7))

ax.barh(top_features, weights, height=0.7)
ax.invert_yaxis()
ax.tick_params(axis='both', which='major', labelsize=20)

# %% [markdown]
# Такие графики можно отрисовать, например, для первых семи топиков:

# %%
def plot_top_words(model, feature_names, n_top_words, title, n_components, max_plots=7):

    fig, axes = plt.subplots(1, max_plots, figsize=(25, 10)) # параметры отображения
    axes = axes.flatten()
    all_features = {} # словарь для сохранения ключевых слов для тем


    for topic_idx, topic in enumerate(model.components_):
      if topic_idx < max_plots:
        top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]

        # строка для сохранения темы и слов в словарь
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f'Topic {topic_idx +1}',
                     fontdict={'fontsize': 13})
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=10)
        for i in 'top right left'.split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=14)


    plt.show()

# %%
plot_top_words(lda, tf_feature_names, 30, 'Распределение слов по темам, LDA-модель', n_components)

# %% [markdown]
# Можно оценить перплексию и log likelihood модели на тестовых данных.

# %%
test_data = fetch_20newsgroups(subset='test')

# %%
X_test = test_data.data

# %%
y_test = test_data.target

# %%
X_test_vectors = tf_vectorizer.transform(X_test)

# %%
lda.perplexity(X_test_vectors)
# Out:
# 19564.25414152984

# %%
lda.score(X_test_vectors)
# Out:
# -384136.7820365759

# %% [markdown]
# ## Использование уменьшенных данных для других задач

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
X_test_lsa = lsa_model.transform(X_test_vectors)
X_test_lda = lda.transform(X_test_vectors)

# %%
X_train_lsa = lsa_topic_matrix
X_train_lda = doc_topic

# %%
y_train = newsgroups.target

# %%
newsgroups.target
# Out:
# array([7, 4, 4, ..., 3, 1, 8])

# %%
knn.fit(X_train_lda, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_preds = knn.predict(X_test_lda)

# %%
print(classification_report(y_test, knn_preds, target_names=newsgroups.target_names))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.29      0.44      0.35       319
#            comp.graphics       0.26      0.42      0.32       389
#  comp.os.ms-windows.misc       0.39      0.46      0.42       394
# comp.sys.ibm.pc.hardware       0.32      0.32      0.32       392
#    comp.sys.mac.hardware       0.27      0.22      0.24       385
#           comp.windows.x       0.54      0.53      0.54       395
#             misc.forsale       0.65      0.75      0.69       390
#                rec.autos       0.26      0.34      0.29       396
#          rec.motorcycles       0.30      0.31      0.31       398
#       rec.sport.baseball       0.45      0.46      0.46       397
#         rec.sport.hockey       0.55      0.52      0.54       399
#                sci.crypt       0.67      0.68      0.68       396
#          sci.electronics       0.13      0.07      0.09       393
#                  sci.med       0.22      0.13      0.17       396
#                sci.space       0.54      0.47      0.50       394
#   soc.religion.christian       0.35      0.52      0.42       398
#       talk.politics.guns       0.41      0.41      0.41       364
#    talk.politics.mideast       0.81      0.56      0.66       376
#       talk.politics.misc       0.32      0.15      0.21       310
#       talk.religion.misc       0.26      0.15      0.19       251
#
#                 accuracy                           0.40      7532
#                macro avg       0.40      0.40      0.39      7532
#             weighted avg       0.40      0.40      0.40      7532

# %%
knn_2 = KNeighborsClassifier(n_neighbors=5)

# %%
knn_2.fit(X_train_lsa, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_2_preds = knn_2.predict(X_test_lsa)

# %%
print(classification_report(y_test, knn_2_preds, target_names=newsgroups.target_names))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.31      0.59      0.41       319
#            comp.graphics       0.31      0.44      0.36       389
#  comp.os.ms-windows.misc       0.43      0.53      0.48       394
# comp.sys.ibm.pc.hardware       0.42      0.43      0.43       392
#    comp.sys.mac.hardware       0.50      0.43      0.46       385
#           comp.windows.x       0.45      0.41      0.43       395
#             misc.forsale       0.53      0.65      0.58       390
#                rec.autos       0.51      0.49      0.50       396
#          rec.motorcycles       0.59      0.59      0.59       398
#       rec.sport.baseball       0.57      0.43      0.49       397
#         rec.sport.hockey       0.73      0.70      0.71       399
#                sci.crypt       0.80      0.58      0.67       396
#          sci.electronics       0.38      0.31      0.34       393
#                  sci.med       0.31      0.37      0.34       396
#                sci.space       0.73      0.64      0.68       394
#   soc.religion.christian       0.63      0.66      0.64       398
#       talk.politics.guns       0.63      0.50      0.55       364
#    talk.politics.mideast       0.83      0.65      0.73       376
#       talk.politics.misc       0.42      0.39      0.40       310
#       talk.religion.misc       0.38      0.24      0.30       251
#
#                 accuracy                           0.51      7532
#                macro avg       0.52      0.50      0.51      7532
#             weighted avg       0.53      0.51      0.51      7532

# %%
cm = confusion_matrix(y_test, knn_2_preds)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
disp.plot(cmap=plt.cm.Greens, ax=ax)
plt.show()

# %%
print([(n, topic) for n, topic in enumerate(newsgroups.target_names)])
# Out:
# [(0, 'alt.atheism'), (1, 'comp.graphics'), (2, 'comp.os.ms-windows.misc'), (3, 'comp.sys.ibm.pc.hardware'), (4, 'comp.sys.mac.hardware'), (5, 'comp.windows.x'), (6, 'misc.forsale'), (7, 'rec.autos'), (8, 'rec.motorcycles'), (9, 'rec.sport.baseball'), (10, 'rec.sport.hockey'), (11, 'sci.crypt'), (12, 'sci.electronics'), (13, 'sci.med'), (14, 'sci.space'), (15, 'soc.religion.christian'), (16, 'talk.politics.guns'), (17, 'talk.politics.mideast'), (18, 'talk.politics.misc'), (19, 'talk.religion.misc')]

# %% [markdown]
# Посмотрим, побивают ли эти результаты модель, обученную на полной матрице векторов:

# %%
knn_baseline = KNeighborsClassifier(n_neighbors=5)

# %%
knn_baseline.fit(X_tf, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_baseline_preds = knn_baseline.predict(X_test_vectors)

# %%
print(classification_report(y_test, knn_baseline_preds, target_names=newsgroups.target_names))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.41      0.55      0.47       319
#            comp.graphics       0.32      0.54      0.41       389
#  comp.os.ms-windows.misc       0.48      0.59      0.53       394
# comp.sys.ibm.pc.hardware       0.38      0.46      0.42       392
#    comp.sys.mac.hardware       0.44      0.45      0.44       385
#           comp.windows.x       0.48      0.48      0.48       395
#             misc.forsale       0.48      0.52      0.50       390
#                rec.autos       0.50      0.46      0.48       396
#          rec.motorcycles       0.62      0.61      0.62       398
#       rec.sport.baseball       0.51      0.50      0.51       397
#         rec.sport.hockey       0.63      0.70      0.66       399
#                sci.crypt       0.75      0.65      0.70       396
#          sci.electronics       0.49      0.33      0.39       393
#                  sci.med       0.56      0.35      0.43       396
#                sci.space       0.71      0.67      0.69       394
#   soc.religion.christian       0.64      0.59      0.61       398
#       talk.politics.guns       0.59      0.52      0.55       364
#    talk.politics.mideast       0.73      0.66      0.69       376
#       talk.politics.misc       0.50      0.36      0.42       310
#       talk.religion.misc       0.40      0.35      0.37       251
#
#                 accuracy                           0.52      7532
#                macro avg       0.53      0.52      0.52      7532
#             weighted avg       0.54      0.52      0.52      7532
